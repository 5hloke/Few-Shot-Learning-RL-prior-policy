# %%
import Data_Prep
import train_Reptile
import train_MAML
import train_iMAML

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = Data_Prep.DataPreparation()

ml10 = data.get_data()
data.construct_episodes(ml10)
X, y, task_lengths = data.prepare_data()
# Out:
# mw/cls_sweep-v2
# mw/cls_push-v2
# mw/cls_door-open-v2
# mw/cls_peg-insert-side-v2
# mw/cls_drawer-close-v2
# mw/cls_basketball-v2
# mw/cls_reach-v2
# mw/cls_window-open-v2
# mw/cls_pick-place-v2
# mw/cls_button_press_topdown-v2

# %%
import torch
input_size = 43
hidden_size1 = 256
hidden_size2 = 256
hidden_size3 = 256

imaml_model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
imaml_train_x, imaml_train_loss, imaml_train_acc = imaml_model.train(X, y, task_lengths, 1000)
#save the model in the models directory
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch: 0, Loss: 0.6536779999732971
#   2%|▎         | 25/1000 [03:15<2:06:18,  7.77s/it]
# Epoch: 25, Loss: 0.5639065504074097
#   5%|▌         | 50/1000 [06:30<2:04:28,  7.86s/it]
# Epoch: 50, Loss: 0.4922066628932953
#   8%|▊         | 75/1000 [09:49<2:01:36,  7.89s/it]
# Epoch: 75, Loss: 0.4451960623264313
#  10%|█         | 100/1000 [13:09<2:01:16,  8.08s/it]
# Epoch: 100, Loss: 0.4110494554042816
#  12%|█▎        | 125/1000 [16:31<1:58:17,  8.11s/it]
# Epoch: 125, Loss: 0.38288605213165283
#  15%|█▌        | 150/1000 [19:51<1:50:48,  7.82s/it]
# Epoch: 150, Loss: 0.35336804389953613
#  18%|█▊        | 175/1000 [23:09<1:47:25,  7.81s/it]
# Epoch: 175, Loss: 0.3474713861942291
#  20%|██        | 200/1000 [26:25<1:43:31,  7.76s/it]
# Epoch: 200, Loss: 0.30480897426605225
#  22%|██▎       | 225/1000 [29:40<1:40:55,  7.81s/it]
# Epoch: 225, Loss: 0.28172755241394043
#  25%|██▌       | 250/1000 [32:55<1:37:01,  7.76s/it]
# ...

# %%
torch.save(imaml_model.model.state_dict(), '../models/imaml_model.pth')

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_drawer-open', prior = True)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_drawer-open-v2
# mw_valid_policy_v1/cls_drawer-open-v1

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_drawer_open_x, imaml_drawer_open_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.7232694029808044
# Epoch: 49, Accuracy: 0.9117597937583923
# Epoch: 74, Accuracy: 0.953461229801178

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_lever-pull', prior = True)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_lever-pull-v2
# mw_valid_policy_v1/cls_lever-pull-v1

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_lever_pull_x, imaml_lever_pull_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.9477898478507996
# Epoch: 49, Accuracy: 0.9581317901611328
# Epoch: 74, Accuracy: 0.9681401252746582

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_shelf-place', prior = True)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_shelf-place-v2
# mw_valid_policy_v1/cls_shelf-place-v1

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_shelf_place_x, imaml_shelf_place_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.6043369770050049
# Epoch: 49, Accuracy: 0.6613844633102417
# Epoch: 74, Accuracy: 0.6735612750053406

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_sweep-into', prior = True)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_sweep-into-v2
# mw_valid_policy_v1/cls_sweep-into-v1

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_sweep_into_x, imaml_sweep_into_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.6241868138313293
# Epoch: 49, Accuracy: 0.536113440990448
# Epoch: 74, Accuracy: 0.5509591102600098

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_drawer-open', prior = False)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_drawer-open-v2

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_no_prior_drawer_open_x, imaml_no_prior_drawer_open_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.765304446220398
# Epoch: 49, Accuracy: 0.8785654902458191
# Epoch: 74, Accuracy: 0.9399499297142029

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_lever-pull', prior = False)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_lever-pull-v2

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_no_prior_lever_pull_x, imaml_no_prior_lever_pull_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.9481234550476074
# Epoch: 49, Accuracy: 0.9492910504341125
# Epoch: 74, Accuracy: 0.9666388630867004

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_shelf-place', prior = False)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_shelf-place-v2

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_no_prior_shelf_place_x, imaml_no_prior_shelf_place_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.7749791741371155
# Epoch: 49, Accuracy: 0.7853211164474487
# Epoch: 74, Accuracy: 0.8030024766921997

# %%
# PEBBLE test with MAML
from pebble import Pebble
# get open drawer data
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, task = 'cls_sweep-into', prior = False)
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()
# Out:
# mw_valid/cls_sweep-into-v2

# %%
model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/imaml_model.pth'))
pebble = Pebble(model)
imaml_no_prior_sweep_into_x, imaml_no_prior_sweep_into_y = pebble.train(X, y, task_lengths, 75)
# Out:
# Epoch: 24, Accuracy: 0.5366138219833374
# Epoch: 49, Accuracy: 0.5301084518432617
# Epoch: 74, Accuracy: 0.5871559381484985

# %%
import numpy as np
np.savetxt('results/imaml/imaml_train_x.txt', imaml_train_x, delimiter=', ')
np.savetxt('results/imaml/imaml_train_loss.txt', imaml_train_loss, delimiter=', ')
np.savetxt('results/imaml/imaml_train_acc.txt', imaml_train_acc, delimiter=', ')
np.savetxt('results/imaml/imaml_drawer_open_x.txt', imaml_drawer_open_x, delimiter=', ')
np.savetxt('results/imaml/imaml_drawer_open_y.txt', imaml_drawer_open_y, delimiter=', ')
np.savetxt('results/imaml/imaml_lever_pull_x.txt', imaml_lever_pull_x, delimiter=', ')
np.savetxt('results/imaml/imaml_lever_pull_y.txt', imaml_lever_pull_y, delimiter=', ')
np.savetxt('results/imaml/imaml_shelf_place_x.txt', imaml_shelf_place_x, delimiter=', ')
np.savetxt('results/imaml/imaml_shelf_place_y.txt', imaml_shelf_place_y, delimiter=', ')
np.savetxt('results/imaml/imaml_sweep_into_x.txt', imaml_sweep_into_x, delimiter=', ')
np.savetxt('results/imaml/imaml_sweep_into_y.txt', imaml_sweep_into_y, delimiter=', ')

# %%
import numpy as np
np.savetxt('results/imaml/imaml_no_prior_drawer_open_x.txt', imaml_no_prior_drawer_open_x, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_drawer_open_y.txt', imaml_no_prior_drawer_open_y, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_lever_pull_x.txt', imaml_no_prior_lever_pull_x, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_lever_pull_y.txt', imaml_no_prior_lever_pull_y, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_shelf_place_x.txt', imaml_no_prior_shelf_place_x, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_shelf_place_y.txt', imaml_no_prior_shelf_place_y, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_sweep_into_x.txt', imaml_no_prior_sweep_into_x, delimiter=', ')
np.savetxt('results/imaml/imaml_no_prior_sweep_into_y.txt', imaml_no_prior_sweep_into_y, delimiter=', ')
