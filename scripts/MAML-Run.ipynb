# %%
import Data_Prep
import train_MAML
import train_MAML
import train_iMAML
from pebble import Pebble

import torch

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data = Data_Prep.DataPreparation()

ml10 = data.get_data()
data.construct_episodes(ml10)
X, y, task_lengths = data.prepare_data()
# Out:
# mw/cls_basketball-v2
# mw/cls_button_press_topdown-v2
# mw/cls_door-open-v2
# mw/cls_drawer-close-v2
# mw/cls_peg-insert-side-v2
# mw/cls_pick-place-v2
# mw/cls_push-v2
# mw/cls_reach-v2
# mw/cls_sweep-v2
# mw/cls_window-open-v2

# %%
input_size = 43
hidden_size1 = 256
hidden_size2 = 256
hidden_size3 = 256

MAML_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
rep_train_pltx, rep_train_plty, rep_train_acc = MAML_model.train(X, y, task_lengths, 1001)
# Out:
#   0%|          | 0/1001 [00:00<?, ?it/s]
# Epoch: 0, Loss: 0.784177839756012, accuracy: 0.4637710452079773
#   1%|          | 6/1001 [01:35<4:24:09, 15.93s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 hidden_size3 = 256
#       6 MAML_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
# ----> 7 rep_train_pltx, rep_train_plty, rep_train_acc = MAML_model.train(X, y, task_lengths, 1001)
#
# File e:\University of Michigan Ann Arbor\UMich Winter Sem 23-24\EECS 545\EECS 545 Project\EECS-545-MLRL\scripts\train_MAML.py:121, in MAML.train(self, X, y, task_lengths, num_epochs)
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=118'>119</a> for epoch in tqdm(range(num_epochs)):
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=119'>120</a>     self.optim.zero_grad()
# --> <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=120'>121</a>     loss, accuracy = self._outer_step(self.model, X, y, task_lengths)
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=121'>122</a>     if loss is None:
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=122'>123</a>         return {}
#
# File e:\University of Michigan Ann Arbor\UMich Winter Sem 23-24\EECS 545\EECS 545 Project\EECS-545-MLRL\scripts\train_MAML.py:156, in MAML._outer_step(self, model, X, y, task_lengths)
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=153'>154</a> outer_y = y_b[H//2:]
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=154'>155</a> weights = self._inner_loop(inner_x, inner_y, model = model)
# --> <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=155'>156</a> loss, acc= self._compute_loss(outer_x, outer_y, model, parameters=weights)
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=156'>157</a> outer_losses.append(loss)
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=157'>158</a> accuracy += acc
#
# File e:\University of Michigan Ann Arbor\UMich Winter Sem 23-24\EECS 545\EECS 545 Project\EECS-545-MLRL\scripts\train_MAML.py:224, in MAML._compute_loss(self, X, y, model, parameters)
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=221'>222</a>             logit = output_reward[j] - output_reward[i]
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=222'>223</a>             pred = logit > 0
# --> <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=223'>224</a>             accuracy += (pred == label).float()
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=224'>225</a>             count += 1
#     <a href='file:///e%3A/University%20of%20Michigan%20Ann%20Arbor/UMich%20Winter%20Sem%2023-24/EECS%20545/EECS%20545%20Project/EECS-545-MLRL/scripts/train_MAML.py?line=225'>226</a> accuracy = accuracy/count
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save model

# %%
torch.save(MAML_model.model.state_dict(), '../models/MAML_model.pth')

# %% [markdown]
# ### Validation

# %% [markdown]
# #### cls_drawer-open

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_drawer-open')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_no_prior_draweropen_pltx, rep_valid_no_prior_draweropen_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_drawer-open-v2
# Epoch: 24, Accuracy: 0.7025854587554932
# Epoch: 49, Accuracy: 0.913594663143158
# Epoch: 74, Accuracy: 0.9618015289306641

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_drawer-open')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_prior_draweropen_pltx, rep_valid_prior_draweropen_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_drawer-open-v2
# mw_valid_policy_v1/cls_drawer-open-v1
# Epoch: 24, Accuracy: 0.7452877163887024
# Epoch: 49, Accuracy: 0.6805671453475952
# Epoch: 74, Accuracy: 0.8748957514762878

# %% [markdown]
# #### cls_lever-pull

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_lever-pull')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_no_prior_leverpull_pltx, rep_valid_no_prior_leverpull_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_lever-pull-v2
# Epoch: 24, Accuracy: 0.9492910504341125
# Epoch: 49, Accuracy: 0.9606338739395142
# Epoch: 74, Accuracy: 0.9654712080955505

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_lever-pull')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_prior_leverpull_pltx, rep_valid_prior_leverpull_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_lever-pull-v2
# mw_valid_policy_v1/cls_lever-pull-v1
# Epoch: 24, Accuracy: 0.9327772855758667
# Epoch: 49, Accuracy: 0.964470386505127
# Epoch: 74, Accuracy: 0.9709758162498474

# %% [markdown]
# #### cls_shelf-place

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_shelf-place')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_no_prior_shelfplace_pltx, rep_valid_no_prior_shelfplace_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_shelf-place-v2
# Epoch: 24, Accuracy: 0.6840700507164001
# Epoch: 49, Accuracy: 0.7567973136901855
# Epoch: 74, Accuracy: 0.7711426019668579

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_shelf-place')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_prior_shelfplace_pltx, rep_valid_prior_shelfplace_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_shelf-place-v2
# mw_valid_policy_v1/cls_shelf-place-v1
# Epoch: 24, Accuracy: 0.7731443047523499
# Epoch: 49, Accuracy: 0.7516263723373413
# Epoch: 74, Accuracy: 0.780316948890686

# %% [markdown]
# #### cls_sweep-into

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_sweep-into')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_no_prior_sweepinto_pltx, rep_valid_no_prior_sweepinto_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_sweep-into-v2
# Epoch: 24, Accuracy: 0.650542140007019
# Epoch: 49, Accuracy: 0.764136791229248
# Epoch: 74, Accuracy: 0.7943286299705505

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_sweep-into')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
rep_valid_prior_sweepinto_pltx, rep_valid_prior_sweepinto_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_sweep-into-v2
# mw_valid_policy_v1/cls_sweep-into-v1
# Epoch: 24, Accuracy: 0.629190981388092
# Epoch: 49, Accuracy: 0.6825687885284424
# Epoch: 74, Accuracy: 0.7487906813621521

# %% [markdown]
# ### Saving the results

# %%
import numpy as np

rep_train_loss = rep_train_plty

# training results
np.savetxt('results/MAML/rep_train_pltx.txt', rep_train_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_train_loss.txt', rep_train_loss, delimiter=', ')
np.savetxt('results/MAML/rep_train_acc.txt', rep_train_acc, delimiter=', ')

# cls_drawer-open
np.savetxt('results/MAML/rep_valid_no_prior_draweropen_pltx.txt', rep_valid_no_prior_draweropen_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_no_prior_draweropen_plty.txt', rep_valid_no_prior_draweropen_plty, delimiter=', ')

np.savetxt('results/MAML/rep_valid_prior_draweropen_pltx.txt', rep_valid_prior_draweropen_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_prior_draweropen_plty.txt', rep_valid_prior_draweropen_plty, delimiter=', ')

# cls_lever-pull
np.savetxt('results/MAML/rep_valid_no_prior_leverpull_pltx.txt', rep_valid_no_prior_leverpull_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_no_prior_leverpull_plty.txt', rep_valid_no_prior_leverpull_plty, delimiter=', ')

np.savetxt('results/MAML/rep_valid_prior_leverpull_pltx.txt', rep_valid_prior_leverpull_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_prior_leverpull_plty.txt', rep_valid_prior_leverpull_plty, delimiter=', ')

# cls_shelf-place
np.savetxt('results/MAML/rep_valid_no_prior_shelfplace_pltx.txt', rep_valid_no_prior_shelfplace_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_no_prior_shelfplace_plty.txt', rep_valid_no_prior_shelfplace_plty, delimiter=', ')

np.savetxt('results/MAML/rep_valid_prior_shelfplace_pltx.txt', rep_valid_prior_shelfplace_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_prior_shelfplace_plty.txt', rep_valid_prior_shelfplace_plty, delimiter=', ')

# cls_sweep-into
np.savetxt('results/MAML/rep_valid_no_prior_sweepinto_pltx.txt', rep_valid_no_prior_sweepinto_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_no_prior_sweepinto_plty.txt', rep_valid_no_prior_sweepinto_plty, delimiter=', ')

np.savetxt('results/MAML/rep_valid_prior_sweepinto_pltx.txt', rep_valid_prior_sweepinto_pltx, delimiter=', ')
np.savetxt('results/MAML/rep_valid_prior_sweepinto_plty.txt', rep_valid_prior_sweepinto_plty, delimiter=', ')

# %%
input_size = 43
hidden_size1 = 256
hidden_size2 = 256
hidden_size3 = 256

# MAML_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
# MAML_model.train(X, y, task_lengths, 2000)

# maml_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
# maml_model.train(X,y,task_lengths,2000)

imaml_model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
imaml_model.train(X,y,task_lengths,2000)
