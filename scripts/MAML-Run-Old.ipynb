# %%
import Data_Prep
import train_MAML
import train_MAML
import train_iMAML
from pebble import Pebble

import torch

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data = Data_Prep.DataPreparation()

ml10 = data.get_data()
data.construct_episodes(ml10)
X, y, task_lengths = data.prepare_data()
# Out:
# mw/cls_sweep-v2
# mw/cls_push-v2
# mw/cls_door-open-v2
# mw/cls_peg-insert-side-v2
# mw/cls_drawer-close-v2
# mw/cls_basketball-v2
# mw/cls_reach-v2
# mw/cls_window-open-v2
# mw/cls_pick-place-v2
# mw/cls_button_press_topdown-v2

# %%
input_size = 43
hidden_size1 = 256
hidden_size2 = 256
hidden_size3 = 256

MAML_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
maml_train_pltx, maml_train_plty, maml_train_acc = MAML_model.train(X, y, task_lengths, 1001)
# Out:
#   0%|          | 0/1001 [00:00<?, ?it/s]
# Epoch: 0, Loss: 0.722772479057312, accuracy: 0.4813467860221863
#   2%|▏         | 25/1001 [00:52<33:59,  2.09s/it]
# Epoch: 25, Loss: 0.5927768349647522, accuracy: 0.6953535079956055
#   5%|▍         | 50/1001 [01:43<32:27,  2.05s/it]
# Epoch: 50, Loss: 0.5395000576972961, accuracy: 0.7523232698440552
#   7%|▋         | 75/1001 [02:35<32:17,  2.09s/it]
# Epoch: 75, Loss: 0.48188266158103943, accuracy: 0.7991918921470642
#  10%|▉         | 100/1001 [03:28<31:37,  2.11s/it]
# Epoch: 100, Loss: 0.43417152762413025, accuracy: 0.8181144595146179
#  12%|█▏        | 125/1001 [04:20<30:28,  2.09s/it]
# Epoch: 125, Loss: 0.41325855255126953, accuracy: 0.8216835260391235
#  15%|█▍        | 150/1001 [05:12<28:34,  2.01s/it]
# Epoch: 150, Loss: 0.3666274845600128, accuracy: 0.8538720011711121
#  17%|█▋        | 175/1001 [06:02<28:02,  2.04s/it]
# Epoch: 175, Loss: 0.35802584886550903, accuracy: 0.8508418202400208
# ...

# %%
import numpy as np
np.savetxt('results/MAML/maml_train_x.txt', maml_train_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_train_loss.txt', maml_train_plty, delimiter=', ')
np.savetxt('results/MAML/maml_train_acc.txt', maml_train_acc, delimiter=', ')

# %% [markdown]
# ### Save model

# %%
torch.save(MAML_model.model.state_dict(), '../models/MAML_model.pth')

# %% [markdown]
# ### Validation

# %% [markdown]
# #### cls_drawer-open

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_drawer-open')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_no_prior_draweropen_pltx, maml_valid_no_prior_draweropen_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_drawer-open-v2
# Epoch: 24, Accuracy: 0.8832360506057739
# Epoch: 49, Accuracy: 0.9276063442230225
# Epoch: 74, Accuracy: 0.96013343334198

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_drawer-open')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_prior_draweropen_pltx, maml_valid_prior_draweropen_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_drawer-open-v2
# mw_valid_policy_v1/cls_drawer-open-v1
# Epoch: 24, Accuracy: 0.8778982758522034
# Epoch: 49, Accuracy: 0.9466221928596497
# Epoch: 74, Accuracy: 0.9664720892906189

# %% [markdown]
# #### cls_lever-pull

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_lever-pull')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_no_prior_leverpull_pltx, maml_valid_no_prior_leverpull_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_lever-pull-v2
# Epoch: 24, Accuracy: 0.8747289180755615
# Epoch: 49, Accuracy: 0.9174311757087708
# Epoch: 74, Accuracy: 0.9352794289588928

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_lever-pull')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_prior_leverpull_pltx, maml_valid_prior_leverpull_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_lever-pull-v2
# mw_valid_policy_v1/cls_lever-pull-v1
# Epoch: 24, Accuracy: 0.9112593531608582
# Epoch: 49, Accuracy: 0.9379482865333557
# Epoch: 74, Accuracy: 0.9399499297142029

# %% [markdown]
# #### cls_shelf-place

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_shelf-place')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_no_prior_shelfplace_pltx, maml_valid_no_prior_shelfplace_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_shelf-place-v2
# Epoch: 24, Accuracy: 0.7883235812187195
# Epoch: 49, Accuracy: 0.7704753875732422
# Epoch: 74, Accuracy: 0.7542952299118042

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_shelf-place')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_prior_shelfplace_pltx, maml_valid_prior_shelfplace_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_shelf-place-v2
# mw_valid_policy_v1/cls_shelf-place-v1
# Epoch: 24, Accuracy: 0.7639699578285217
# Epoch: 49, Accuracy: 0.7933277487754822
# Epoch: 74, Accuracy: 0.8113427758216858

# %% [markdown]
# #### cls_sweep-into

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=False, task = 'cls_sweep-into')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_no_prior_sweepinto_pltx, maml_valid_no_prior_sweepinto_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_sweep-into-v2
# Epoch: 24, Accuracy: 0.7476230263710022
# Epoch: 49, Accuracy: 0.8325271010398865
# Epoch: 74, Accuracy: 0.83469557762146

# %%
vdata = Data_Prep.DataPreparation()
valid = vdata.get_data(validation= True, prior=True, task = 'cls_sweep-into')
vdata.construct_episodes(valid)
X, y, task_lengths = vdata.prepare_data()

model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
model.model.load_state_dict(torch.load('../models/MAML_model.pth'))
pebble = Pebble(model)
maml_valid_prior_sweepinto_pltx, maml_valid_prior_sweepinto_plty = pebble.train(X, y, task_lengths, 76)
# Out:
# mw_valid/cls_sweep-into-v2
# mw_valid_policy_v1/cls_sweep-into-v1
# Epoch: 24, Accuracy: 0.7237697839736938
# Epoch: 49, Accuracy: 0.8088406920433044
# Epoch: 74, Accuracy: 0.8370308876037598

# %% [markdown]
# ### Saving the results

# %%
import numpy as np

# maml_train_loss = maml_train_plty

# # training results
# np.savetxt('results/MAML/maml_train_pltx.txt', maml_train_pltx, delimiter=', ')
# np.savetxt('results/MAML/maml_train_loss.txt', maml_train_loss, delimiter=', ')
# np.savetxt('results/MAML/maml_train_acc.txt', maml_train_acc, delimiter=', ')

# cls_drawer-open
np.savetxt('results/MAML/maml_valid_no_prior_draweropen_pltx.txt', maml_valid_no_prior_draweropen_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_no_prior_draweropen_plty.txt', maml_valid_no_prior_draweropen_plty, delimiter=', ')

np.savetxt('results/MAML/maml_valid_prior_draweropen_pltx.txt', maml_valid_prior_draweropen_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_prior_draweropen_plty.txt', maml_valid_prior_draweropen_plty, delimiter=', ')

# cls_lever-pull
np.savetxt('results/MAML/maml_valid_no_prior_leverpull_pltx.txt', maml_valid_no_prior_leverpull_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_no_prior_leverpull_plty.txt', maml_valid_no_prior_leverpull_plty, delimiter=', ')

np.savetxt('results/MAML/maml_valid_prior_leverpull_pltx.txt', maml_valid_prior_leverpull_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_prior_leverpull_plty.txt', maml_valid_prior_leverpull_plty, delimiter=', ')

# cls_shelf-place
np.savetxt('results/MAML/maml_valid_no_prior_shelfplace_pltx.txt', maml_valid_no_prior_shelfplace_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_no_prior_shelfplace_plty.txt', maml_valid_no_prior_shelfplace_plty, delimiter=', ')

np.savetxt('results/MAML/maml_valid_prior_shelfplace_pltx.txt', maml_valid_prior_shelfplace_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_prior_shelfplace_plty.txt', maml_valid_prior_shelfplace_plty, delimiter=', ')

# cls_sweep-into
np.savetxt('results/MAML/maml_valid_no_prior_sweepinto_pltx.txt', maml_valid_no_prior_sweepinto_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_no_prior_sweepinto_plty.txt', maml_valid_no_prior_sweepinto_plty, delimiter=', ')

np.savetxt('results/MAML/maml_valid_prior_sweepinto_pltx.txt', maml_valid_prior_sweepinto_pltx, delimiter=', ')
np.savetxt('results/MAML/maml_valid_prior_sweepinto_plty.txt', maml_valid_prior_sweepinto_plty, delimiter=', ')

# %%
# input_size = 43
# hidden_size1 = 256
# hidden_size2 = 256
# hidden_size3 = 256

# MAML_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
# MAML_model.train(X, y, task_lengths, 2000)

# maml_model = train_MAML.MAML(input_size, hidden_size1, hidden_size2, hidden_size3)
# maml_model.train(X,y,task_lengths,2000)

# imaml_model = train_iMAML.iMAML(input_size, hidden_size1, hidden_size2, hidden_size3)
# imaml_model.train(X,y,task_lengths,2000)
